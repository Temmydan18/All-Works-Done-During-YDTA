# %%
# Write a program to add any two numbers
num1 = 20
num2 = 10
answer = num1+num2
print (answer)
# Out:
# 30

# %%
surname = 'Shuaib'
age = 30
age = '30'

# %%
age =20
print(age*3)
# Out:
# 60

# %% [markdown]
# num1=5
# num2=10
# print(num1+num2)

# %%
nums = [10, 5, 8, 20]
nums [-1]
# Out:
# 20

# %%
len(nums)
# Out:
# 4

# %%
sum(nums)
# Out:
# 43

# %%
average= sum(nums)/len(nums)
print(average)
# Out:
# 10.75

# %%
#logical and comparison operators
#working loops
#using if..elif..else statement
#accessing excel file for data analysis

# %%
# AND, NAND, NOR, OR,
==, !=,

# %%
a = 40
b = 30
a > b ? AND a < b ?
a <= b OR a >= b ?
F or F > f OR T or F > t

F OR T = T

# %%
b = 25
c = 30

b==b OR (b>=c) AND (c==b)
b==b > T or T > T
b>=c > F or F > F
c==b > F or F > F
b>=c AND c==b > F
T(b==b) or F > T

# %%
nums = [5, 6, 8, 3, 2]
for n in nums:
    print(n)

# %%
products = []

while True:
    p = input('Enter product name: ')
    products.append(p)
    print('Product added')
    print(products)
    Q = input('Do you want to continue? yes/no')
    if Q=='no':
        print('Thank you for using the app')
        break

# %%
#Guess Game
import random
score = 0
live = 5
player = input('Enter your name:')
print(f'Hi, {player}. Welcome to playstation!')
while True: 
    if live == 0:
        print('Gameover!')
        break
    systemGuess = random.randint (1, 6)
    myGuess = int(input('Guess a number: '))
    if systemGuess == myGuess:
        print(f'Great! System guessed {systemGuess}')
        score = score+5
        print(f' Your new score is {score}')
    else:
        print(f'Sorry! System guessed {systemGuess}')
        score = score-5
        live = live-1
        print(f' Your new score is {score} and live left is {live}')

# %%
num = int(input("Enter a number for multiplication table"))
for n in range (1, 13):
        print(f'{num}* {n} = {num*n}')
# Out:
# Enter a number for multiplication table 12
# 12* 1 = 12
# 12* 2 = 24
# 12* 3 = 36
# 12* 4 = 48
# 12* 5 = 60
# 12* 6 = 72
# 12* 7 = 84
# 12* 8 = 96
# 12* 9 = 108
# 12* 10 = 120
# 12* 11 = 132
# 12* 12 = 144

# %%
nums= [1

# %%
#create contact book
books = []
num = int(input('how many books do you want to add?'))
for n in range(num):
    bookName = input('enter book name: ')
    phonenumber = input('enter phone number: ')
    book = {
        'name': bookName,
        'phone': phonenumber
    },
    
    books.append(book)
    print('All books are added')
    
    Q = input('Do you want to continue? yes/no')
    if Q=='no':
        print('Thank you for using the app')
        break
# Out:
# how many books do you want to add? 4
# enter book name:  tech
# enter phone number:  333233
# All books are added
# Do you want to continue? yes/no no
# Thank you for using the app

# %%
profile = {
    'firstname': 'temi',
    'lastname': 'daniel',
    'age': 21,
    'address': {
        'state': 'lagos',
        'country': 'Nigeria',
        'LGA': 'fadeyi'
    },
    'matricno' : 'f/ND/24/3740094'}

# %%
print(profile)
# Out:
# {'firstname': 'temi', 'lastname': 'daniel', 'age': 21, 'address': {'state': 'lagos', 'country': 'Nigeria', 'LGA': 'fadeyi'}, 'matricno': 'f/ND/24/3740094'}

# %%
profile
# Out:
# {'firstname': 'temi',
#  'lastname': 'daniel',
#  'age': 21,
#  'address': {'state': 'lagos', 'country': 'Nigeria', 'LGA': 'fadeyi'},
#  'matricno': 'f/ND/24/3740094'}

# %%
#guessgame

# %%
num = int(input('automatic multiplication table'))
for n in range (1,15):
    print(f'{num}*{n} = {num*n}')
# Out:
# automatic multiplication table 12
# 12*1 = 12
# 12*2 = 24
# 12*3 = 36
# 12*4 = 48
# 12*5 = 60
# 12*6 = 72
# 12*7 = 84
# 12*8 = 96
# 12*9 = 108
# 12*10 = 120
# 12*11 = 132
# 12*12 = 144
# 12*13 = 156
# 12*14 = 168

# %%
nums = [10, 2, [3,4], [5,8]]
nums[0]
# Out:
# 10

# %%
#what is a function?
#A reusable piece of codeto perform a specific task

# %%
#Write a function to add any two numbers
num1 =50
num2= 20
print(num1+num2)
# Out:
# 70

# %%
def Addition (n1, n2):
    return n1+n2
def Subtraction (n1, n2):
    return n1-n2
def Multiplication (n1, n2):
    return n1*n2
def Division (n1, n2):
    return n1/n2

# %%
Addition(Subtraction(10, 5), Multiplication(6, 4))
# Out:
# 29

# %%
output = Addition(60, 30)
print(output)
# Out:
# 90

# %%
\\\
