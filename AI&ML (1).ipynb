# %%
products = []

while True:
    p = input('Enter product name: ')
    products.append(p)
    print('Product added')
    print(products)
    Q = input('Do you want to continue? yes/no')
    if Q=='no':
        print('Thank you for using the app')
        break
# Out:
# Enter product name:  addidas
# Product added
# ['addidas']
# Do you want to continue? yes/no yes
# Enter product name:  addidas
# Product added
# ['addidas', 'addidas']
# Do you want to continue? yes/no no
# Thank you for using the app

# %%
#Guess Game
import random
score = 0
live = 5
player = input('Enter your name:')
print(f'Hi, {player}. Welcome to playstation!')
while True: 
    if live == 0:
        print('Gameover!')
        break
    systemGuess = random.randint (1, 6)
    myGuess = int(input('Guess a number: '))
    if systemGuess == myGuess:
        print(f'Great! System guessed {systemGuess}')
        score = score+5
        print(f' Your new score is {score}')
    else:
        print(f'Sorry! System guessed {systemGuess}')
        score = score-5
        live = live-1
        print(f' Your new score is {score} and live left is {live}')
# Out:
# Enter your name: temmydan
# Hi, temmydan. Welcome to playstation!
# Guess a number:  4
# Sorry! System guessed 6
#  Your new score is -5 and live left is 4
# Guess a number:  1
# Sorry! System guessed 4
#  Your new score is -10 and live left is 3
# Guess a number:  2
# Sorry! System guessed 1
#  Your new score is -15 and live left is 2
# Guess a number:  3
# Sorry! System guessed 1
#  Your new score is -20 and live left is 1
# Guess a number:  0
# Sorry! System guessed 4
#  Your new score is -25 and live left is 0
# Gameover!
